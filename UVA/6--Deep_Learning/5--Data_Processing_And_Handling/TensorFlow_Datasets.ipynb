# %%
import tensorflow_datasets as tfds

# %%
ds = tfds.load('ai2_arc_with_ir', split = 'train', shuffle_files = True)

# %%
excerpt = ds.take(1)
for example in excerpt:
  print('Example:')
  print(example)
  print('\nAnswer Key:')
  print(example['answerKey'])
  print('\nChoices:')
  print(example['choices'])
  print('\nID:')
  print(example['id'])
  print('\nParagraph:')
  print(example['paragraph'])
  print('\nQuestion:')
  print(example['question'])
# Out:
# Example:
# {'answerKey': <tf.Tensor: shape=(), dtype=int64, numpy=2>, 'choices': {'label': <tf.Tensor: shape=(4,), dtype=int64, numpy=array([0, 1, 2, 3])>, 'text': <tf.Tensor: shape=(4,), dtype=string, numpy=
# array([b'are low-density gases.', b'are not abundant on Earth.',
#        b'have complete outermost energy levels.',
#        b'have two electrons in their outermost energy level.'],
#       dtype=object)>}, 'id': <tf.Tensor: shape=(), dtype=string, numpy=b'Mercury_401011'>, 'paragraph': <tf.Tensor: shape=(), dtype=string, numpy=b'It and the other noble gases - helium, neon, krypton, xenon, and radon - will react with other substances only under extreme conditions. The noble gases The noble, or inert, gases are helium, neon, argon, krypton, xenon and radon. The rare gases are helium, neon, argon, krypton or xenon. The noble "gases" are helium, neon, argon, krypton and xenon. The noble gases are helium, neon, argon, krypton, xenon and radon. These occur for the noble gases helium, neon, argon, krypton, xenon, radon and ununoctium. Because of their chemical inertness, the elements in this group are called the Nobel Gases : Helium Neon Argon Krypton Xenon Radon Group I Elements The elements in this group have one electron in their outer electronic shell. The inert, or noble, gases (helium, neon, argon, krypton, xenon, and radon) all have completely filled outer shells. The other noble gases, which together make about 1% of the Earth\'s atmosphere, are neon, argon, krypton, xenon and radon. Most of the noble gases-helium, neon, argon, krypton, xenon, and radon-are rare.'>, 'question': <tf.Tensor: shape=(), dtype=string, numpy=b'The noble gases, helium, neon, argon, krypton, xenon, and radon, rarely react with other elements because they'>}
#
# Answer Key:
# tf.Tensor(2, shape=(), dtype=int64)
#
# Choices:
# {'label': <tf.Tensor: shape=(4,), dtype=int64, numpy=array([0, 1, 2, 3])>, 'text': <tf.Tensor: shape=(4,), dtype=string, numpy=
# array([b'are low-density gases.', b'are not abundant on Earth.',
#        b'have complete outermost energy levels.',
#        b'have two electrons in their outermost energy level.'],
#       dtype=object)>}
#
# ID:
# tf.Tensor(b'Mercury_401011', shape=(), dtype=string)
#
# Paragraph:
# tf.Tensor(b'It and the other noble gases - helium, neon, krypton, xenon, and radon - will react with other substances only under extreme conditions. The noble gases The noble, or inert, gases are helium, neon, argon, krypton, xenon and radon. The rare gases are helium, neon, argon, krypton or xenon. The noble "gases" are helium, neon, argon, krypton and xenon. The noble gases are helium, neon, argon, krypton, xenon and radon. These occur for the noble gases helium, neon, argon, krypton, xenon, radon and ununoctium. Because of their chemical inertness, the elements in this group are called the Nobel Gases : Helium Neon Argon Krypton Xenon Radon Group I Elements The elements in this group have one electron in their outer electronic shell. The inert, or noble, gases (helium, neon, argon, krypton, xenon, and radon) all have completely filled outer shells. The other noble gases, which together make about 1% of the Earth\'s atmosphere, are neon, argon, krypton, xenon and radon. Most of the noble gases-helium, neon, argon, krypton, xenon, and radon-are rare.', shape=(), dtype=string)
#
# Question:
# tf.Tensor(b'The noble gases, helium, neon, argon, krypton, xenon, and radon, rarely react with other elements because they', shape=(), dtype=string)

# %%
def convert_to_alphanumeric(string):
  return ''.join(char for char in string if char.isalnum())

# %%
import re
def tokenize(string):
  list_of_tokens = []
  list_of_substrings = re.split(' |-', string)
  for substring in list_of_substrings:
    token = convert_to_alphanumeric(substring).lower()
    list_of_tokens.append(token)
  return list_of_tokens

# %%
def process(dictionary_of_tokens_and_frequencies, list_of_strings):
  for string in list_of_strings:
    list_of_tokens = tokenize(string)
    for token in list_of_tokens:
      if token in dictionary_of_tokens_and_frequencies.keys():
        dictionary_of_tokens_and_frequencies[token] = dictionary_of_tokens_and_frequencies[token] + 1
      else:
        dictionary_of_tokens_and_frequencies[token] = 1

# %%
dictionary_of_tokens_and_frequencies = {}
for example in ds:
  process(dictionary_of_tokens_and_frequencies, [byte_array.decode('utf-8') for byte_array in example['choices']['text'].numpy().tolist()])
  process(dictionary_of_tokens_and_frequencies, [example['paragraph'].numpy().decode('utf-8')])
  process(dictionary_of_tokens_and_frequencies, [example['question'].numpy().decode('utf-8')])
dictionary_of_tokens_and_frequencies = dict(sorted(dictionary_of_tokens_and_frequencies.items(), key=lambda item: item[1], reverse = True))
dictionary_of_tokens_and_frequencies
# Out:
# {'the': 19030,
#  'of': 9739,
#  'and': 7391,
#  'a': 6561,
#  'to': 5343,
#  'in': 5136,
#  'is': 4499,
#  '': 2938,
#  'which': 2757,
#  'are': 2207,
#  'that': 2021,
#  'water': 2021,
#  'from': 1811,
#  'as': 1602,
#  'on': 1545,
#  'for': 1517,
#  'by': 1414,
#  'or': 1395,
#  'it': 1338,
#  'with': 1335,
#  'energy': 1306,
#  'an': 1236,
#  'be': 1194,
#  'can': 934,
#  'most': 900,
#  'have': 892,
#  'earth': 869,
#  'this': 845,
#  'will': 828,
#  'at': 823,
#  'plants': 754,
#  'when': 738,
#  'has': 709,
#  'they': 708,
#  'into': 650,
#  'its': 612,
#  'one': 601,
#  'than': 588,
#  'not': 581,
#  'other': 580,
#  'sun': 562,
#  'what': 550,
#  'their': 539,
#  'these': 517,
#  'was': 513,
#  'more': 492,
#  'use': 490,
#  'all': 483,
#  'how': 467,
#  'carbon': 466,
#  'plant': 454,
#  'food': 445,
#  'used': 440,
#  'air': 436,
#  'soil': 434,
#  'mass': 433,
#  'chemical': 431,
#  'temperature': 430,
#  'light': 428,
#  'different': 402,
#  'two': 399,
#  'if': 393,
#  'like': 386,
#  'same': 384,
#  'many': 382,
#  'system': 380,
#  '2': 379,
#  'such': 378,
#  'would': 376,
#  'but': 372,
#  'cells': 370,
#  'change': 336,
#  'you': 336,
#  'through': 334,
#  'heat': 333,
#  'some': 332,
#  'between': 331,
#  'moon': 327,
#  'species': 316,
#  'about': 315,
#  'dioxide': 314,
#  'animals': 313,
#  'each': 307,
#  'students': 307,
#  'cell': 306,
#  'form': 305,
#  'there': 303,
#  'amount': 299,
#  'following': 297,
#  'up': 296,
#  'body': 295,
#  'surface': 295,
#  'gas': 294,
#  'liquid': 291,
#  'time': 290,
#  'example': 290,
#  'organisms': 290,
#  'oxygen': 288,
#  'do': 287,
#  'likely': 285,
#  'only': 281,
#  'because': 281,
#  'ice': 278,
#  'rocks': 277,
#  'best': 272,
#  'rock': 267,
#  'new': 265,
#  'changes': 265,
#  'solar': 263,
#  'down': 262,
#  'using': 262,
#  'make': 258,
#  'were': 257,
#  'human': 257,
#  '1': 256,
#  'force': 255,
#  'during': 254,
#  'also': 252,
#  'does': 251,
#  'found': 251,
#  'made': 250,
#  'ocean': 239,
#  'around': 237,
#  'earths': 234,
#  'then': 233,
#  'data': 233,
#  'trees': 232,
#  'ball': 231,
#  'over': 231,
#  'atmosphere': 230,
#  'wind': 229,
#  'solid': 226,
#  'fish': 225,
#  'so': 222,
#  'scientists': 220,
#  'no': 215,
#  'process': 215,
#  'may': 214,
#  'produce': 213,
#  'color': 210,
#  'number': 210,
#  'natural': 207,
#  'years': 205,
#  'we': 204,
#  'large': 200,
#  'both': 197,
#  'cycle': 195,
#  'small': 193,
#  'rain': 192,
#  'stars': 191,
#  'less': 191,
#  'distance': 188,
#  'been': 185,
#  'fossil': 184,
#  '10': 183,
#  'increase': 183,
#  'life': 182,
#  'results': 179,
#  'our': 176,
#  'high': 174,
#  'electrical': 173,
#  'speed': 172,
#  'size': 171,
#  'them': 170,
#  'electricity': 169,
#  'where': 169,
#  'physical': 169,
#  'birds': 168,
#  'object': 166,
#  'area': 165,
#  'way': 164,
#  'called': 162,
#  'white': 162,
#  'he': 162,
#  'coal': 161,
#  'sugar': 161,
#  'type': 160,
#  'temperatures': 160,
#  'sound': 160,
#  'student': 158,
#  '3': 157,
#  'out': 156,
#  'why': 154,
#  'acid': 153,
#  'tree': 152,
#  'your': 152,
#  'animal': 152,
#  'plate': 152,
#  'should': 150,
#  'result': 150,
#  'oil': 150,
#  'people': 149,
#  'cause': 148,
#  'move': 148,
#  'photosynthesis': 148,
#  'salt': 148,
#  'resources': 147,
#  'after': 146,
#  'first': 146,
#  'forest': 146,
#  'formed': 145,
#  'egg': 145,
#  'star': 145,
#  'day': 144,
#  'much': 144,
#  'living': 144,
#  'paper': 144,
#  'table': 144,
#  'material': 143,
#  'source': 143,
#  'weather': 143,
#  'fuels': 143,
#  'elements': 142,
#  'offspring': 142,
#  'reproduction': 142,
#  'part': 140,
#  'car': 140,
#  'population': 139,
#  'volume': 139,
#  'matter': 138,
#  'very': 138,
#  'sunlight': 137,
#  'blood': 137,
#  'times': 136,
#  'fuel': 136,
#  'grams': 136,
#  'substances': 135,
#  'long': 134,
#  'materials': 134,
#  'being': 134,
#  'growth': 134,
#  'kinetic': 134,
#  'together': 132,
#  'his': 131,
#  'she': 131,
#  'types': 131,
#  'grow': 130,
#  'flowers': 130,
#  'due': 130,
#  'bacteria': 130,
#  'waves': 130,
#  'similar': 130,
#  '100': 129,
#  'sea': 129,
#  'erosion': 129,
#  'function': 129,
#  'molecules': 129,
#  'c': 128,
#  'x': 128,
#  'environment': 128,
#  'help': 128,
#  'common': 128,
#  'motion': 127,
#  'state': 126,
#  'could': 124,
#  'hydrogen': 124,
#  'atom': 124,
#  'live': 123,
#  'important': 123,
#  'pollution': 121,
#  'warm': 121,
#  'levels': 120,
#  'i': 120,
#  'electric': 120,
#  'place': 119,
#  'increases': 119,
#  'atoms': 119,
#  'produced': 118,
#  'determine': 117,
#  'volcanic': 117,
#  'gasoline': 117,
#  'while': 116,
#  'increased': 116,
#  'away': 116,
#  'glass': 116,
#  'axis': 116,
#  'structure': 115,
#  'average': 115,
#  'occurs': 114,
#  'year': 114,
#  'weight': 114,
#  'experiment': 114,
#  'ms': 113,
#  'include': 113,
#  'nutrients': 113,
#  'gravity': 113,
#  'planet': 113,
#  'electrons': 112,
#  'vapor': 112,
#  'must': 112,
#  'effect': 112,
#  'systems': 112,
#  'products': 112,
#  'several': 112,
#  'metal': 112,
#  'work': 111,
#  'well': 111,
#  'measure': 111,
#  'point': 111,
#  'properties': 111,
#  'moving': 111,
#  'red': 110,
#  'caused': 110,
#  'describes': 110,
#  'objects': 110,
#  'land': 109,
#  'three': 109,
#  'core': 109,
#  'another': 108,
#  'layers': 108,
#  'causes': 108,
#  'off': 108,
#  'ph': 108,
#  'substance': 107,
#  'planets': 107,
#  'low': 106,
#  'group': 106,
#  'leaves': 106,
#  'organic': 106,
#  'element': 106,
#  '4': 105,
#  'ecosystem': 105,
#  'wood': 105,
#  'any': 105,
#  'sky': 105,
#  'processes': 105,
#  'boiling': 105,
#  'her': 104,
#  'nucleus': 104,
#  '5': 104,
#  'contains': 103,
#  'occur': 102,
#  'organism': 102,
#  'information': 102,
#  'areas': 102,
#  'characteristics': 102,
#  'take': 101,
#  'larger': 101,
#  'power': 101,
#  'particles': 101,
#  's': 100,
#  'shape': 100,
#  'including': 100,
#  'direction': 100,
#  'o': 100,
#  'hot': 99,
#  'takes': 99,
#  'b': 99,
#  'deer': 99,
#  'reaction': 99,
#  'renewable': 99,
#  'winter': 99,
#  'north': 99,
#  'see': 98,
#  'oceans': 98,
#  'space': 98,
#  'eggs': 97,
#  '6': 96,
#  'potential': 96,
#  'plastic': 96,
#  'level': 95,
#  'atomic': 95,
#  'cold': 95,
#  'burning': 95,
#  'four': 94,
#  'near': 94,
#  'forms': 93,
#  'current': 93,
#  'every': 93,
#  'mechanical': 93,
#  'get': 93,
#  'hypothesis': 93,
#  'become': 92,
#  'describe': 92,
#  'theory': 92,
#  'gases': 91,
#  'eat': 91,
#  'green': 91,
#  'ecosystems': 91,
#  'single': 91,
#  'pressure': 91,
#  'graph': 91,
#  'kg': 90,
#  'genes': 90,
#  'unit': 90,
#  'circuit': 89,
#  'gene': 89,
#  'lakes': 89,
#  'night': 89,
#  'model': 89,
#  'climate': 89,
#  'layer': 89,
#  'once': 88,
#  'activity': 88,
#  'insects': 88,
#  'respiration': 88,
#  'heavy': 87,
#  'flow': 87,
#  'south': 87,
#  '20': 86,
#  'put': 86,
#  'wave': 86,
#  'below': 86,
#  'populations': 86,
#  'research': 86,
#  'mixture': 86,
#  'had': 85,
#  'habitat': 85,
#  'fossils': 85,
#  'decrease': 84,
#  'skin': 84,
#  'solution': 84,
#  'evaporation': 84,
#  'often': 83,
#  'parts': 83,
#  'lower': 83,
#  'minerals': 83,
#  'sample': 83,
#  'aluminum': 83,
#  'back': 82,
#  'bird': 82,
#  'since': 82,
#  'constant': 82,
#  'sedimentary': 82,
#  'field': 81,
#  'even': 81,
#  'ability': 81,
#  'study': 81,
#  'states': 81,
#  'rate': 81,
#  'density': 80,
#  'resource': 80,
#  'lake': 80,
#  'contain': 80,
#  'parents': 80,
#  'trait': 80,
#  'gravitational': 80,
#  'changed': 79,
#  'good': 79,
#  'within': 79,
#  'increasing': 79,
#  'under': 78,
#  'before': 78,
#  'seeds': 78,
#  'production': 78,
#  'dna': 78,
#  'just': 77,
#  'waste': 77,
#  'need': 77,
#  'sources': 77,
#  'usually': 77,
#  'available': 76,
#  'disease': 76,
#  'center': 76,
#  'ground': 76,
#  'moves': 76,
#  'adult': 76,
#  'compounds': 76,
#  'graphs': 76,
#  'support': 75,
#  'provide': 75,
#  'battery': 75,
#  'above': 75,
#  'ago': 75,
#  'tall': 74,
#  'soils': 74,
#  'sand': 74,
#  'find': 74,
#  'precipitation': 74,
#  'snow': 74,
#  'liquids': 74,
#  'river': 74,
#  '50': 74,
#  'sexual': 74,
#  'days': 74,
#  'short': 73,
#  'means': 73,
#  'affect': 73,
#  'orbit': 73,
#  'cup': 73,
#  'building': 73,
#  'velocity': 72,
#  'm': 72,
#  'released': 72,
#  'reduce': 72,
#  'cellular': 72,
#  'various': 72,
#  'per': 71,
#  'know': 71,
#  'those': 71,
#  'who': 71,
#  'uses': 71,
#  'major': 71,
#  'weathering': 71,
#  'line': 71,
#  'nonrenewable': 71,
#  'mountain': 71,
#  'reactions': 71,
#  'mars': 71,
#  'algae': 70,
#  'makes': 70,
#  'mineral': 70,
#  'melting': 70,
#  'floor': 70,
#  'chromosomes': 70,
#  'galaxy': 69,
#  'known': 69,
#  'top': 68,
#  'based': 68,
#  'bulb': 68,
#  'blue': 68,
#  'behavior': 68,
#  'metals': 68,
#  'molecule': 68,
#  'statement': 67,
#  'however': 67,
#  'smaller': 67,
#  'h': 67,
#  'eye': 67,
#  'along': 67,
#  'heart': 67,
#  'hair': 67,
#  'without': 66,
#  'now': 66,
#  'humans': 66,
#  'simple': 66,
#  'waters': 66,
#  'compound': 66,
#  'characteristic': 66,
#  'ml': 66,
#  'iron': 66,
#  'container': 65,
#  'summer': 65,
#  'clouds': 65,
#  'global': 65,
#  'formation': 65,
#  'functions': 65,
#  'learn': 65,
#  'samples': 65,
#  'non': 65,
#  'wire': 64,
#  'few': 64,
#  'test': 64,
#  'science': 64,
#  'crust': 64,
#  'complete': 63,
#  'seed': 63,
#  'movement': 63,
#  'nervous': 63,
#  'largest': 63,
#  'fungi': 63,
#  'explains': 63,
#  'organ': 63,
#  'changing': 62,
#  'placed': 62,
#  'covered': 62,
#  'rivers': 62,
#  'pieces': 62,
#  'local': 62,
#  'scale': 62,
#  'melt': 62,
#  'better': 61,
#  'plates': 61,
#  'million': 61,
#  'record': 60,
#  'stored': 60,
#  'investigation': 60,
#  'build': 60,
#  'open': 60,
#  'dogs': 60,
#  'effects': 60,
#  'environmental': 60,
#  'genetic': 60,
#  'ways': 60,
#  'sodium': 60,
#  'freezing': 60,
#  '12': 59,
#  'needed': 59,
#  'thus': 59,
#  'technology': 59,
#  'development': 59,
#  'side': 59,
#  'order': 59,
#  'includes': 59,
#  'organs': 59,
#  'faster': 59,
#  'present': 59,
#  'masses': 59,
#  'periodic': 59,
#  'outer': 58,
#  'certain': 58,
#  'experiments': 58,
#  'turn': 58,
#  'eg': 58,
#  'continental': 58,
#  'deep': 58,
#  'health': 58,
#  'nitrogen': 58,
#  'igneous': 58,
#  'discovered': 58,
#  'forces': 58,
#  'moons': 58,
#  'corn': 58,
#  'radiation': 58,
#  '15': 58,
#  'universe': 58,
#  'measured': 57,
#  'us': 57,
#  'property': 57,
#  'mostly': 57,
#  'forests': 57,
#  'roots': 57,
#  'becomes': 57,
#  'tectonics': 57,
#  'least': 57,
#  'n': 57,
#  'cars': 57,
#  'second': 56,
#  'fire': 56,
#  'greatest': 56,
#  'insect': 56,
#  'black': 56,
#  'seen': 56,
#  'greater': 56,
#  'inherited': 56,
#  'impact': 56,
#  'nest': 56,
#  'dominant': 55,
#  'given': 55,
#  'thermal': 55,
#  'own': 55,
#  'colored': 55,
#  'always': 55,
#  'causing': 55,
#  'dark': 55,
#  'evidence': 55,
#  'produces': 55,
#  'case': 55,
#  'neutrons': 55,
#  'dissolved': 55,
#  'multicellular': 55,
#  'stream': 55,
#  'control': 54,
#  'either': 54,
#  'total': 54,
#  'until': 54,
#  'frequency': 54,
#  'making': 54,
#  'chemicals': 54,
#  'explain': 54,
#  '8': 53,
#  'among': 53,
#  'tropical': 53,
#  'keep': 53,
#  'cut': 53,
#  'world': 53,
#  'atmospheric': 53,
#  'metamorphic': 53,
#  'higher': 53,
#  'protons': 53,
#  'road': 53,
#  'eyes': 53,
#  'inside': 53,
#  'observe': 53,
#  'male': 53,
#  'release': 52,
#  'crops': 52,
#  'amounts': 52,
#  'cannot': 52,
#  't': 52,
#  'upon': 52,
#  'season': 52,
#  'look': 52,
#  'observed': 52,
#  'groups': 52,
#  'reproduce': 52,
#  'bodies': 52,
#  'rotation': 52,
#  'scientific': 51,
#  'primary': 51,
#  'set': 51,
#  'smooth': 51,
#  'clear': 51,
#  'possible': 51,
#  'mountains': 51,
#  'turbines': 51,
#  'tissue': 51,
#  'comes': 51,
#  'examples': 51,
#  'astronomical': 51,
#  'electron': 50,
#  'half': 50,
#  'product': 50,
#  'recycled': 50,
#  'quality': 50,
#  'seasons': 50,
#  'brain': 50,
#  'affected': 50,
#  'main': 50,
#  'nuclear': 50,
#  'observations': 50,
#  'y': 50,
#  'balloon': 50,
#  'great': 49,
#  '7': 49,
#  'across': 49,
#  'yellow': 49,
#  'directly': 49,
#  'basic': 49,
#  'next': 49,
#  'break': 49,
#  'quickly': 49,
#  'warming': 49,
#  'solids': 49,
#  'enough': 49,
#  'streams': 49,
#  'g': 49,
#  'young': 49,
#  'degrees': 49,
#  'sheep': 49,
#  'america': 49,
#  'copper': 48,
#  'galaxies': 48,
#  '30': 48,
#  'tissues': 48,
#  'activities': 48,
#  'emissions': 48,
#  'batteries': 48,
#  'tectonic': 48,
#  'give': 48,
#  'mercury': 48,
#  'laboratory': 48,
#  'female': 48,
#  'fresh': 48,
#  'helium': 47,
#  'conditions': 47,
#  'true': 47,
#  'frog': 47,
#  'happens': 47,
#  'colors': 47,
#  'perform': 47,
#  'approximately': 47,
#  'greenhouse': 47,
#  'pure': 47,
#  'travel': 47,
#  'moisture': 47,
#  'd': 47,
#  'close': 47,
#  'etc': 47,
#  'definite': 47,
#  'create': 47,
#  'magnetic': 47,
#  'mantle': 47,
#  'orange': 47,
#  'phase': 46,
#  'loss': 46,
#  'identify': 46,
#  'chain': 46,
#  'able': 46,
#  'history': 46,
#  'related': 46,
#  'teeth': 46,
#  'range': 46,
#  'cool': 46,
#  'height': 46,
#  'remove': 46,
#  'glucose': 46,
#  'milk': 46,
#  'bar': 46,
#  'circulatory': 46,
#  'marine': 45,
#  'question': 45,
#  'lead': 45,
#  'difference': 45,
#  'forming': 45,
#  'instead': 45,
#  'convert': 45,
#  'dry': 45,
#  'membrane': 45,
#  'digestive': 45,
#  'traits': 45,
#  'growing': 45,
#  'flows': 45,
#  'having': 45,
#  'containing': 45,
#  'survive': 45,
#  'muscle': 45,
#  'structures': 45,
#  'equator': 45,
#  'balls': 45,
#  'hill': 45,
#  'fast': 44,
#  'add': 44,
#  'might': 44,
#  'resulting': 44,
#  'relationship': 44,
#  'community': 44,
#  'factors': 44,
#  'helps': 44,
#  'millions': 44,
#  'milky': 44,
#  'broken': 44,
#  'glaciers': 44,
#  'frogs': 44,
#  'evaporates': 44,
#  'except': 44,
#  'fur': 44,
#  'bottom': 44,
#  'tides': 44,
#  'jupiter': 44,
#  'melted': 44,
#  'display': 44,
#  'spring': 44,
#  'arctic': 44,
#  'closer': 44,
#  'wool': 44,
#  'warmer': 43,
#  'easily': 43,
#  'length': 43,
#  'hand': 43,
#  '25': 43,
#  'flower': 43,
#  'absorb': 43,
#  'grass': 43,
#  'supply': 43,
#  'prey': 43,
#  'far': 43,
#  'run': 43,
#  'desert': 43,
#  'specific': 43,
#  'equal': 43,
#  'piece': 43,
#  'muscles': 43,
#  'eruptions': 43,
#  'considered': 42,
#  'determined': 42,
#  'too': 42,
#  'response': 42,
#  'show': 42,
#  'full': 42,
#  'motor': 42,
#  'return': 42,
#  'series': 42,
#  'today': 42,
#  'units': 42,
#  'kingdom': 42,
#  'decreases': 42,
#  'depth': 42,
#  'cans': 42,
#  'uranus': 42,
#  'allows': 41,
#  'fly': 41,
#  'predators': 41,
#  'still': 41,
#  'opposite': 41,
#  'pull': 41,
#  'city': 41,
#  'places': 41,
#  'almost': 41,
#  'computer': 41,
#  'appear': 41,
#  'little': 41,
#  'mammals': 41,
#  'dead': 41,
#  'separate': 41,
#  'school': 41,
#  'decreased': 41,
#  'negative': 41,
#  'friction': 41,
#  'celsius': 41,
#  'old': 41,
#  'visible': 41,
#  'period': 40,
#  'although': 40,
#  'especially': 40,
#  'room': 40,
#  'term': 40,
#  'protect': 40,
#  'billion': 40,
#  'dog': 40,
#  'apart': 40,
#  'parent': 40,
#  'inclined': 40,
#  'fact': 40,
#  'prevent': 40,
#  'measuring': 40,
#  'winds': 40,
#  'medium': 40,
#  'plane': 40,
#  'classified': 40,
#  'hemisphere': 40,
#  'identical': 40,
#  'meter': 40,
#  'juice': 40,
#  'did': 39,
#  'answer': 39,
#  'fall': 39,
#  'outside': 39,
#  'converted': 39,
#  'remains': 39,
#  'added': 39,
#  'butterflies': 39,
#  'whether': 39,
#  'scientist': 39,
#  'fox': 39,
#  'brown': 39,
#  'sperm': 39,
#  'meters': 38,
#  'left': 38,
#  'things': 38,
#  'consists': 38,
#  'web': 38,
#  'evolution': 38,
#  'variety': 38,
#  'sediment': 38,
#  'last': 38,
#  'generally': 38,
#  'oceanic': 38,
#  'nutrient': 38,
#  'percent': 38,
#  'atlantic': 38,
#  'features': 38,
#  'feed': 38,
#  'metamorphosis': 38,
#  'models': 38,
#  'according': 38,
#  'goes': 38,
#  'throughout': 38,
#  'patterns': 38,
#  'minutes': 38,
#  'chocolate': 38,
#  'rotates': 38,
#  'develop': 37,
#  'position': 37,
#  'heating': 37,
#  'safety': 37,
#  'complex': 37,
#  'provides': 37,
#  'strong': 37,
#  'generation': 37,
#  'conservation': 37,
#  'freshwater': 37,
#  'toward': 37,
#  'sulfur': 37,
#  'age': 37,
#  'foods': 37,
#  'composition': 37,
#  'cover': 37,
#  'united': 37,
#  'recycling': 37,
#  'required': 37,
#  'continents': 37,
#  'pan': 37,
#  'bicycle': 37,
#  'longer': 37,
#  'planetary': 37,
#  'pole': 37,
#  'euglena': 37,
#  'against': 36,
#  'sex': 36,
#  'flowered': 36,
#  'pea': 36,
#  'homozygous': 36,
#  'gives': 36,
#  'nature': 36,
#  'person': 36,
#  'teacher': 36,
#  'direct': 36,
#  'action': 36,
#  'suns': 36,
#  'events': 36,
#  'heated': 36,
#  'gets': 36,
#  'clay': 36,
#  'wear': 36,
#  'conduct': 36,
#  'magma': 36,
#  'asexual': 36,
#  'relative': 36,
#  'km': 36,
#  'resistance': 36,
#  'bulbs': 36,
#  'rubber': 36,
#  'crossed': 35,
#  'fusion': 35,
#  'absorbed': 35,
#  'said': 35,
#  'site': 35,
#  'twice': 35,
#  'exactly': 35,
#  'celled': 35,
#  'device': 35,
#  'glacier': 35,
#  'children': 35,
#  'orbits': 35,
#  'circle': 35,
#  'pupa': 35,
#  'stages': 35,
#  'equation': 35,
#  'fruit': 35,
#  ...}

# %%
len(dictionary_of_tokens_and_frequencies)
# Out:
# 15091

# %% [markdown]
# `ai2_arc_with_ir` is a dataset of 7,787 grade school level multiple-choice science questions assembled to encourage research in answering of questions and common-sense reasoning.
#
# Through basic loading using TensorFlow Datasets, iteration through examples, and tokenization into words, I discovered about 15,091 words.
#
# The top 10 most frequent words and their frequencies, excluding the empty string, are as follows.
#
# {'the': 19030,
# 'of': 9739,
# 'and': 7391,
# 'a': 6561,
# 'to': 5343,
# 'in': 5136,
# 'is': 4499,
# '': 2938,
# 'which': 2757,
# 'are': 2207,
# 'that': 2021}
#
# Challenges involve understanding whether all examples are accounted for, extracting relevant strings from each example, tokenizing strings, and processing a lot of data.
