# %% [markdown]
# # Getting started with pandas

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
# 6.1
df = pd.DataFrame({'features': [0.2, -1.1, 1.6, 5.4], 'labels': [0, 1, 1, 0]})
df
# Out:
#    features  labels
# 0       0.2       0
# 1      -1.1       1
# 2       1.6       1
# 3       5.4       0

# %%
# 2
df = df.rename(columns = {'labels': 'label'})
df.columns = ['features', 'label']
df
# Out:
#    features  label
# 0       0.2      0
# 1      -1.1      1
# 2       1.6      1
# 3       5.4      0

# %%
# 3
iris = sns.load_dataset('iris')
iris.sort_values(by = ['species'], ascending = False)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 149           5.9          3.0           5.1          1.8  virginica
# 111           6.4          2.7           5.3          1.9  virginica
# 122           7.7          2.8           6.7          2.0  virginica
# 121           5.6          2.8           4.9          2.0  virginica
# 120           6.9          3.2           5.7          2.3  virginica
# ..            ...          ...           ...          ...        ...
# 31            5.4          3.4           1.5          0.4     setosa
# 30            4.8          3.1           1.6          0.2     setosa
# 29            4.7          3.2           1.6          0.2     setosa
# 28            5.2          3.4           1.4          0.2     setosa
# 0             5.1          3.5           1.4          0.2     setosa
#
# [150 rows x 5 columns]

# %%
# 4
iris['species'].value_counts().to_frame('value count')
# Out:
#             value count
# setosa               50
# versicolor           50
# virginica            50

# %%
# 5
len(iris[(iris['petal_length'] <= 1.4) | (iris['petal_length'] >= 1.6)])
iris[(iris['petal_length'] <= 1.4) | (iris['petal_length'] >= 1.6)].shape[0]
# Out:
# 137

# %%
# 6
iris['min_petal'] = iris.apply(lambda x: min(x['petal_length'], x['petal_width']), axis = 1)
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      min_petal
# 0          0.2
# 1          0.2
# 2          0.2
# 3          0.2
# 4          0.2
# ..         ...
# 145        2.3
# ...

# %%
# 6
print(sum(iris.petal_length <= iris.petal_width))
iris[['petal_length', 'petal_width']].idxmin(axis = 1).value_counts()
# Out:
# 0
# petal_width    150
# dtype: int64

# %%
# 7
pd.pivot_table(iris, values = ['sepal_width', 'petal_width'], columns = ['species'], aggfunc = {np.mean, np.median})
# Out:
# species             setosa  versicolor  virginica
# petal_width mean     0.246       1.326      2.026
#             median   0.200       1.300      2.000
# sepal_width mean     3.428       2.770      2.974
#             median   3.400       2.800      3.000
